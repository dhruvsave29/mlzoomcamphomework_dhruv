# %%
import numpy as np
import pandas as pd

# %%
data = [['nissan', 2010, 10000], ['honda', 2012, 15000], ['toyota', 2015, 20000]]

df = pd.DataFrame(data, columns=['Make', 'Year', 'Price'])

# %%
df.head(n = 1)

# %%
df.Year

# %%
import pandas as pd
import numpy as np

cars_data = {
    "Car_ID": [101, 102, 103, 104, 105],
    "Brand": ["Toyota", "Honda", "Tesla", "BMW", "Hyundai"],
    "Model": ["Camry", "Civic", "Model 3", "X5", "Creta"],
    
    # Missing values added
    "Year": [2022, 2021, 2023, np.nan, 2024],
    
    "Color": ["White", "Black", "Red", "Blue", "Grey"],
    "Fuel_Type": ["Petrol", "Diesel", "Electric", "Diesel", "Petrol"],
    "Transmission": ["Automatic", "Manual", "Automatic", "Automatic", "Manual"],
    
    # Missing values
    "Engine_CC": [2500, 1800, 0, np.nan, 1500],
    "Mileage_kmpl": [15, 20, np.nan, 12, 18],
    
    "Price_USD": [30000, 25000, 45000, 60000, 22000],
    "Horsepower": [203, 158, 283, 335, 115],
    
    # Missing values
    "Seating_Capacity": [5, np.nan, 5, 7, 5],
    "Safety_Rating": [np.nan, 5, 5, 5, 4],
    
    "Sunroof": [True, False, True, True, False],
    "Navigation_System": [True, True, True, True, False]
}

# Create DataFrame
df = pd.DataFrame(cars_data)

print(df)
# Out:
#    Car_ID    Brand    Model    Year  Color Fuel_Type Transmission  Engine_CC  \
# 0     101   Toyota    Camry  2022.0  White    Petrol    Automatic     2500.0
# 1     102    Honda    Civic  2021.0  Black    Diesel       Manual     1800.0
# 2     103    Tesla  Model 3  2023.0    Red  Electric    Automatic        0.0
# 3     104      BMW       X5     NaN   Blue    Diesel    Automatic        NaN
# 4     105  Hyundai    Creta  2024.0   Grey    Petrol       Manual     1500.0
#
#    Mileage_kmpl  Price_USD  Horsepower  Seating_Capacity  Safety_Rating  \
# 0          15.0      30000         203               5.0            NaN
# 1          20.0      25000         158               NaN            5.0
# 2           NaN      45000         283               5.0            5.0
# 3          12.0      60000         335               7.0            5.0
# 4          18.0      22000         115               5.0            4.0
#
#    Sunroof  Navigation_System
# 0     True               True
# 1    False               True
# 2     True               True
# 3     True               True
# 4    False              False

# %%
df = pd.DataFrame(cars_data)

# %%
df

# %%
df.head(n = 4)

# %%
df[["Color", "Price_USD"]    ]

# %%
df

# %%
df['model id'] =[238,32,32,24,214]

# %%
df

# %%
del df['model id']

# %%
df

# %%
df.index

# %%
df.loc[1]

# %%
df[df['Year'] > 2023]

# %%
df

# %%
'STRr'.lower()

# %%
df['Model'] = df['Model'].str.replace(' ', '_').str.lower()

# %%
df
# Out:
#    Car_ID    Brand    Model    Year  Color Fuel_Type Transmission  Engine_CC  \
# 0     101   Toyota    Camry  2022.0  White    Petrol    Automatic     2500.0
# 1     102    Honda    Civic  2021.0  Black    Diesel       Manual     1800.0
# 2     103    Tesla  Model 3  2023.0    Red  Electric    Automatic        0.0
# 3     104      BMW       X5     NaN   Blue    Diesel    Automatic        NaN
# 4     105  Hyundai    Creta  2024.0   Grey    Petrol       Manual     1500.0
#
#    Mileage_kmpl  Price_USD  Horsepower  Seating_Capacity  Safety_Rating  \
# 0          15.0      30000         203               5.0            NaN
# 1          20.0      25000         158               NaN            5.0
# 2           NaN      45000         283               5.0            5.0
# 3          12.0      60000         335               7.0            5.0
# 4          18.0      22000         115               5.0            4.0
#
#    Sunroof  Navigation_System
# 0     True               True
# 1    False               True
# 2     True               True
# 3     True               True
# 4    False              False

# %%
df['Price_USD'].describe()

# %%
df.describe().round(0)

# %%
df['Model'].nunique()

# %%
df.isnull().sum()

# %%
df.groupby('Transmission').Price_USD.mean()
# Out:
# Transmission
# Automatic    45000.0
# Manual       23500.0
# Name: Price_USD, dtype: float64

# %%
df.Price_USD.values
# Out:
# array([30000, 25000, 45000, 60000, 22000])

# %%
df.to_dict(orient='records')
# Out:
# [{'Car_ID': 101,
#   'Brand': 'Toyota',
#   'Model': 'Camry',
#   'Year': 2022.0,
#   'Color': 'White',
#   'Fuel_Type': 'Petrol',
#   'Transmission': 'Automatic',
#   'Engine_CC': 2500.0,
#   'Mileage_kmpl': 15.0,
#   'Price_USD': 30000,
#   'Horsepower': 203,
#   'Seating_Capacity': 5.0,
#   'Safety_Rating': nan,
#   'Sunroof': True,
#   'Navigation_System': True},
#  {'Car_ID': 102,
#   'Brand': 'Honda',
#   'Model': 'Civic',
#   'Year': 2021.0,
#   'Color': 'Black',
#   'Fuel_Type': 'Diesel',
#   'Transmission': 'Manual',
#   'Engine_CC': 1800.0,
#   'Mileage_kmpl': 20.0,
#   'Price_USD': 25000,
#   'Horsepower': 158,
#   'Seating_Capacity': nan,
#   'Safety_Rating': 5.0,
#   'Sunroof': False,
#   'Navigation_System': True},
#  {'Car_ID': 103,
#   'Brand': 'Tesla',
#   'Model': 'Model 3',
#   'Year': 2023.0,
#   'Color': 'Red',
#   'Fuel_Type': 'Electric',
#   'Transmission': 'Automatic',
#   'Engine_CC': 0.0,
#   'Mileage_kmpl': nan,
#   'Price_USD': 45000,
#   'Horsepower': 283,
#   'Seating_Capacity': 5.0,
#   'Safety_Rating': 5.0,
#   'Sunroof': True,
#   'Navigation_System': True},
#  {'Car_ID': 104,
#   'Brand': 'BMW',
#   'Model': 'X5',
#   'Year': nan,
#   'Color': 'Blue',
#   'Fuel_Type': 'Diesel',
#   'Transmission': 'Automatic',
#   'Engine_CC': nan,
#   'Mileage_kmpl': 12.0,
#   'Price_USD': 60000,
#   'Horsepower': 335,
#   'Seating_Capacity': 7.0,
#   'Safety_Rating': 5.0,
#   'Sunroof': True,
#   'Navigation_System': True},
#  {'Car_ID': 105,
#   'Brand': 'Hyundai',
#   'Model': 'Creta',
#   'Year': 2024.0,
#   'Color': 'Grey',
#   'Fuel_Type': 'Petrol',
#   'Transmission': 'Manual',
#   'Engine_CC': 1500.0,
#   'Mileage_kmpl': 18.0,
#   'Price_USD': 22000,
#   'Horsepower': 115,
#   'Seating_Capacity': 5.0,
#   'Safety_Rating': 4.0,
#   'Sunroof': False,
#   'Navigation_System': False}]

# %%
df.to_json()
# Out:
# '{"Car_ID":{"0":101,"1":102,"2":103,"3":104,"4":105},"Brand":{"0":"Toyota","1":"Honda","2":"Tesla","3":"BMW","4":"Hyundai"},"Model":{"0":"Camry","1":"Civic","2":"Model 3","3":"X5","4":"Creta"},"Year":{"0":2022.0,"1":2021.0,"2":2023.0,"3":null,"4":2024.0},"Color":{"0":"White","1":"Black","2":"Red","3":"Blue","4":"Grey"},"Fuel_Type":{"0":"Petrol","1":"Diesel","2":"Electric","3":"Diesel","4":"Petrol"},"Transmission":{"0":"Automatic","1":"Manual","2":"Automatic","3":"Automatic","4":"Manual"},"Engine_CC":{"0":2500.0,"1":1800.0,"2":0.0,"3":null,"4":1500.0},"Mileage_kmpl":{"0":15.0,"1":20.0,"2":null,"3":12.0,"4":18.0},"Price_USD":{"0":30000,"1":25000,"2":45000,"3":60000,"4":22000},"Horsepower":{"0":203,"1":158,"2":283,"3":335,"4":115},"Seating_Capacity":{"0":5.0,"1":null,"2":5.0,"3":7.0,"4":5.0},"Safety_Rating":{"0":null,"1":5.0,"2":5.0,"3":5.0,"4":4.0},"Sunroof":{"0":true,"1":false,"2":true,"3":true,"4":false},"Navigation_System":{"0":true,"1":true,"2":true,"3":true,"4":false}}'
